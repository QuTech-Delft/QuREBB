# %%
import sys
from os.path import expanduser, join
import copy
home = expanduser("~")
sys.path.append(join(home, 'Repositories/QuREBB'))

import numpy as np
import matplotlib.pyplot as plt
import lib.protocol as protocol
from protocols.tutorial_protocols import ProtocolA, ProtocolB, ProtocolC

# %%
save_path = "simulations_preprint/"

common_params = {
    'gamma_dephasing': 30.5e6,
    'splitting': 1e9,
    'DW': 0.7,
    'QE': 0.2,
    'link_loss': 0.99,
    'insertion_loss': 0.5,
    'dim': 3,
    'dc_rate': 0,
    'ideal': False
}

projector_params = {
    'f_operation': 0e9,
    'delta': 0e9,
    'kappa_r': 21.8e9/2,
    'kappa_t': 21.8e9/2, 
    'gamma': 92.5e6,
    'g': 8.38e9,
    'dc_rate': 0.000,
}

emission_params = {
    'f_operation': 0e9,
    'delta': 0e9,
    'kappa_in': 240e9,
    'kappa_loss': 89e9, 
    'gamma': 100e6,
    'g': 6.81e9,
    'alpha': 0.1
}
projector_params.update(common_params)
emission_params.update(common_params)

# %% [markdown]
# # Simulate Basic Protocols

# %% [markdown]
# ## Protocol A

# %%
sweep_params_emission ={   
    'alpha' : np.linspace(0.0000001, 0.3, 500)
}

# %%
ps_A = protocol.ProtocolSweep(ProtocolA, emission_params, sweep_params_emission, save_results=True, save_folder=save_path, save_name='ProtocolA')

# %%
ps_A.run()
# Out:
# Sweep time with multi was 75.051 s

# %%
ps_A.dataset.fidelity.plot()

# %%
ps_A.generate_fidelity_rate_curve()
ps_A.save_dataset_fidelity_rate()

# %%
ps_A.dataset_fidelity_rate.fidelity.plot(xscale='log', marker='.')

# %% [markdown]
# ## Protocol B

# %%
sweep_params_projector ={
    
    'delta': np.linspace(0e9,120e9, int(60)),
    
    'f_operation': np.linspace(-18e9,0e9, int(1000)),
}

# %%
ps_B = protocol.ProtocolSweep(ProtocolB, projector_params, sweep_params_projector,save_results=True, save_folder=save_path, save_name='ProtocolB')

# %%
ps_B.run()
# Out:
# Sweep time with multi was 7472.769 s

# %%
fig, ax = plt.subplots(1,2)
ps_B.dataset.fidelity.plot(ax=ax[0])
ps_B.dataset.rate.plot(ax=ax[1])

# %%
ps_B.generate_fidelity_rate_curve()
ps_B.save_dataset_fidelity_rate()

# %%
ps_B.dataset_fidelity_rate.fidelity.plot(xscale='log', marker='.')

# %% [markdown]
# ## Protocol C

# %%
ps_C  = protocol.ProtocolSweep(ProtocolC, projector_params, sweep_params_projector, save_results=True, save_folder=save_path, save_name='ProtocolC')

# %%
ps_C.run()
# Out:
# Sweep time with multi was 3432.280 s

# %%
ps_C.dataset
# Out:
# <xarray.Dataset>
# Dimensions:      (delta: 60, f_operation: 1000)
# Coordinates:
#   * delta        (delta) float64 0.0 2.034e+09 4.068e+09 ... 1.18e+11 1.2e+11
#   * f_operation  (f_operation) float64 -1.8e+10 -1.798e+10 ... -1.802e+07 0.0
# Data variables:
#     fidelity     (delta, f_operation) float64 0.5192 0.5199 0.5207 ... 0.5 0.5
#     rate         (delta, f_operation) float64 9.106e-07 8.573e-07 ... 0.0006199
# Attributes: (12/13)
#     kappa_r:          10900000000.0
#     kappa_t:          10900000000.0
#     gamma:            92500000.0
#     g:                8380000000.0
#     dc_rate:          0
#     gamma_dephasing:  30500000.0
#     ...               ...
#     DW:               0.7
#     QE:               0.2
#     link_loss:        0.99
#     insertion_loss:   0.5
#     dim:              3
#     ideal:            False

# %%
fig, ax = plt.subplots(1,2)
ps_C.dataset.fidelity.plot(ax=ax[0])
ps_C.dataset.rate.plot(ax=ax[1])

# %%
ps_C.generate_fidelity_rate_curve()
ps_C.save_dataset_fidelity_rate()

# %%
ps_C.dataset_fidelity_rate.fidelity.plot(xscale='linear')

# %% [markdown]
# ## Protocol C with WCS

# %%
sweep_params_wcs ={
    'delta': np.linspace(0e9,120e9, int(30)),
    'f_operation': np.linspace(-15e9,1e9, int(501)),
    'alpha': np.linspace( np.sqrt(0.0001) , np.sqrt(2.) , int(10))
}

projector_params.update("dim", 4)

# %%
ps_C_wcs  = protocol.ProtocolSweep(ProtocolC, projector_params, sweep_params_wcs)

# %%
ps_C_wcs.run()

# %%
ps_C_wcs.dataset.fidelity.plot()

# %% [markdown]
# # Plotting

# %%
fig, ax = plt.subplots()

(1-ps_A.dataset_fidelity_rate.fidelity).plot(ax=ax, label='Protocol A', marker='.', linestyle='--')
(1-ps_B.dataset_fidelity_rate.fidelity).plot(ax=ax, label='Protocol B', marker='.', linestyle='--')
(1-ps_C.dataset_fidelity_rate.fidelity).plot(ax=ax, label='Protocol C', marker='.', linestyle='--')


ax.hlines(0.5, 1e-12,1, color='k', linestyle='--')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1e-12, 1)
ax.set_ylabel('Infidelity')
plt.legend(loc=2)

# %%
print(np.max(ps_A.dataset.fidelity.values))
print(np.max(ps_B.dataset.fidelity.values))
print(np.max(ps_C.dataset.fidelity.values))
# Out:
# 0.9670103346269597
# 0.9941688084028155
# 0.9941688117947478

# %% [markdown]
# # Cooperativity Sweep

# %%
common_params = {
    'gamma_dephasing': 30.5e6,
    'splitting': 1e9,
    'DW': 0.7,
    'QE': 0.2,
    'link_loss': 0.99,
    'insertion_loss': 0.5,
    'dim': 3,
    'dc_rate': 0,
    'ideal': False
}

projector_params = {
    'f_operation': 0e9,
    'delta': 0e9,
    'kappa_r': 21.8e9/2,
    'kappa_t': 21.8e9/2, 
    'gamma': 92.5e6,
    'g': 8.38e9,
    'dc_rate': 0.000,
}

projector_params.update(common_params)

# %%
parameter_sweep_dict = {
    "1":
    {"delta": np.linspace(-0.6e10, 0.2e10, 50), 
     "f_operation": np.linspace(-2e9, 4e9, 1001)},
    
    "10":
    {"delta":np.linspace(-1.2e10, 0.4e10, 50), 
     "f_operation":np.linspace(-1e9, 5e9, 1001)},
 
    "50":
    {"delta":np.linspace(-1.5e10, 0.8e10, 50), 
     "f_operation":np.linspace(0e9, 10e9, 1001)},
    
    "100":
    {"delta":np.linspace(-1.5e10, 0.8e10, 50), 
     "f_operation":np.linspace(1e9, 12e9, 1001)},
    
    "200":
    {"delta":np.linspace(-1.8e10, 1.e10, 50), 
     "f_operation":np.linspace(1e9, 25e9, 1001)},
    
    "500":
    {"delta":np.linspace(-4e10, 1.0e10, 50), 
     "f_operation":np.linspace(1e9, 25e9, 1001)},
    
    "1000":
    {"delta":np.linspace(-4e10, 1.0e10, 50), 
     "f_operation":np.linspace(5e9, 25e9, 1001)},
    
#     "2500":
#     {"delta":np.linspace(-5e10, 1.0e10, 50), 
#      "f_operation":np.linspace(5e9, 30e9, 1501)},
    
#     "5000":
#     {"delta":np.linspace(-6e10, 1.0e10, 50), 
#      "f_operation":np.linspace(5e9, 35e9, 1501)},
}

# %%
sweep_params_projector ={
    
    'delta': np.linspace(0e9,120e9, int(60)),
    
    'f_operation': np.linspace(-18e9,0e9, int(1000)),
}

c_sweep = np.array([1, 10, 50, 100, 200, 500, 1000])

protocol_sweep_objects_kappa = {}

kappa_params = copy.deepcopy(projector_params)

for c in c_sweep:
    kappa_tot = 4*kappa_params['g']**2/(kappa_params['gamma']+kappa_params['gamma_dephasing'])/c
    kappa_params.update({'kappa_r': kappa_tot/2})
    kappa_params.update({'kappa_t': kappa_tot/2})

    sweep_params = sweep_params_projector

    ps_coop  = protocol.ProtocolSweep(ProtocolC, kappa_params, sweep_params, save_results=True, save_folder=save_path, save_name=f"CoopSweepKappa_C{int(c)}")

    ps_coop.run()
    ps_coop.generate_fidelity_rate_curve()
    ps_coop.save_dataset_fidelity_rate()

    protocol_sweep_objects_kappa.update({str(c): ps_coop})
# Out:
# Sweep time with multi was 4361.002 s
# Sweep time with multi was 3420.869 s
# Sweep time with multi was 3497.305 s
# Sweep time with multi was 3517.648 s
# Sweep time with multi was 3538.501 s
# Sweep time with multi was 3507.254 s
# Sweep time with multi was 3495.994 s

# %%
protocol_sweep_objects_g = {}

g_params = copy.deepcopy(projector_params)

for c in c_sweep:
    g = np.sqrt( c * (g_params['kappa_r']+g_params['kappa_t']) * (g_params['gamma']+g_params['gamma_dephasing'])/4  )
    g_params.update({'g': g})
    sweep_params = parameter_sweep_dict[str(c)]

    ps_coop  = protocol.ProtocolSweep(ProtocolC, g_params, sweep_params, save_results=True, save_folder=save_path, save_name=f"CoopSweepG_C{int(c)}")

    ps_coop.run()
    ps_coop.generate_fidelity_rate_curve()
    ps_coop.save_dataset_fidelity_rate()

    protocol_sweep_objects_g.update({str(c): ps_coop})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 6
#       3 g_params = copy.deepcopy(projector_params)
#       5 for c in c_sweep:
# ----> 6     g = np.sqrt( c * (g_params['kappa_in']+g_params['kappa_loss']) * (g_params['gamma']+g_params['gamma_dephasing'])/4  )
#       7     g_params.update({'g': g})
#       8     sweep_params = parameter_sweep_dict[str(c)]
#
# KeyError: 'kappa_in'

# %% [markdown]
# # Testing

# %%
sweep_params={'f_operation': np.linspace(-10e9, 10e9, 5), "delta": np.linspace(-10e11, 10e11, 5)}

# %%
sweep_params ={
    
    'delta': np.linspace(-100e9,100e9, int(20)),
    
    'f_operation': np.linspace(-15e9,15e9, int(100)),
}

# %%
ps = protocol.ProtocolSweep(ProtocolC, projector_params, sweep_params)

# %%
ps.run()
# Out:
# Sweep time with multi was 126.136 s

# %%
ps.dataset.fidelity.plot()

# %%
ps.dataset.rate.plot()

# %%
ps.generate_fidelity_rate_curve()

# %%
ps.dataset_fidelity_rate
# Out:
# <xarray.Dataset>
# Dimensions:      (rate: 100)
# Coordinates:
#     delta        (rate) float64 6.667e+10 7.778e+10 ... 2.222e+10 2.222e+10
#     f_operation  (rate) float64 -4.01e+09 -4.01e+09 ... -1.241e+10 -1.241e+10
#   * rate         (rate) float64 2.759e-09 0.001717 0.003435 ... 0.1683 0.17
# Data variables:
#     fidelity     (rate) float64 0.988 0.9831 0.9633 ... 0.7184 0.7184 0.7184
# Attributes: (12/13)
#     kappa_r:          10900000000.0
#     kappa_t:          10900000000.0
#     gamma:            92500000.0
#     g:                8380000000.0
#     dc_rate:          0
#     gamma_dephasing:  30500000.0
#     ...               ...
#     DW:               0.7
#     QE:               0.2
#     link_loss:        0.99
#     insertion_loss:   0.5
#     dim:              3
#     ideal:            False

# %%
ps.dataset_fidelity_rate.fidelity.plot()

# %%
ps.save_folder = "~/Desktop/simulation_datasets"

# %%
ps.save_dataset()

# %%
protocol.load_dataset("~/Desktop/simulation_datasets/20231006-153749-225-dataset.hdf5").attrs
# Out:
# {'kappa_r': 10900000000.0,
#  'kappa_t': 10900000000.0,
#  'gamma': 92500000.0,
#  'g': 8380000000.0,
#  'dc_rate': 0,
#  'gamma_dephasing': 30500000.0,
#  'splitting': 1000000000.0,
#  'DW': 0.7,
#  'QE': 0.2,
#  'link_loss': 0.99,
#  'insertion_loss': 0.5,
#  'dim': 3,
#  'ideal': False}
